# %%
# !pip install PyMySQL
# !pip install mysql-connector-python
import pandas as pd
from sqlalchemy import create_engine
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.4 MB 1.0 MB/s eta 0:00:16
#    --- ------------------------------------ 1.3/16.4 MB 1.3 MB/s eta 0:00:12
#    --- ------------------------------------ 1.6/16.4 MB 1.3 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.1/16.4 MB 1.4 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.4/16.4 MB 1.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 2.4/16.4 MB 1.5 MB/s eta 0:00:10
#    ------- -------------------------------- 2.9/16.4 MB 1.4 MB/s eta 0:00:10
# ...

# %%
df1 = pd.read_csv("clean_transactions.csv")
df2 = pd.read_csv("accounts_clean.csv")
df3 = pd.read_csv("clean_customer.csv")
df4 = pd.read_csv("clean_loan.csv")

# %% [markdown]
# ## Ensure to craete the database at the MySQL first before

# %%
engine = create_engine("mysql+mysqlconnector://root:123passWord@localhost/bank_data")

# %% [markdown]
# ## At this point, attach tables (i.e transactions, loan, etc) to the already created database in MySQL

# %%
df1.to_sql(
    name='dftransactions',     # table name in MySQL
    con=engine,              # database connection
    if_exists='replace',     # 'replace' overwrites, 'append' adds new rows
    index=False              # don’t write DataFrame index as a column
)
# Out:
# 40

# %%
df2.to_sql(
    name='accounts',     # table name in MySQL
    con=engine,              # database connection
    if_exists='replace',     # 'replace' overwrites, 'append' adds new rows
    index=False              # don’t write DataFrame index as a column
)
# Out:
# 20

# %%
df3.to_sql(
    name='customers',     # table name in MySQL
    con=engine,              # database connection
    if_exists='replace',     # 'replace' overwrites, 'append' adds new rows
    index=False              # don’t write DataFrame index as a column
)
# Out:
# 20

# %%
df4.to_sql(
    name='loans',     # table name in MySQL
    con=engine,              # database connection
    if_exists='replace',     # 'replace' overwrites, 'append' adds new rows
    index=False              # don’t write DataFrame index as a column
)
# Out:
# 10
